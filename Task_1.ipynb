# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
# reading the csv file
df=pd.read_csv('Iris.csv',index_col='Id')
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
df['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.plot()

# %%
species=['Iris-setosa','Iris-virginica','Iris-versicolor']
color=['red','blue','green']
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['SepalLengthCm'],x['SepalWidthCm'],color=color[i],label=species[i])
plt.legend(loc='upper right')
plt.title('Iris dataset scatterplot')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
species=['Iris-setosa','Iris-virginica','Iris-versicolor']
color=['red','blue','green']
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['PetalLengthCm'],x['PetalWidthCm'],color=color[i],label=species[i])
plt.legend(loc='upper left')
plt.title('Iris dataset scatterplot')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
species=['Iris-setosa','Iris-virginica','Iris-versicolor']
color=['red','blue','green']
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['SepalLengthCm'],x['PetalLengthCm'],color=color[i],label=species[i])
plt.legend(loc='upper left')
plt.title('Iris dataset scatterplot')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
species=['Iris-setosa','Iris-virginica','Iris-versicolor']
color=['red','blue','green']
for i in range(3):
    x=df[df['Species']==species[i]]
    plt.scatter(x['SepalWidthCm'],x['PetalWidthCm'],color=color[i],label=species[i])
plt.legend(loc='upper right')
plt.title('Iris dataset scatterplot')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
df_sw=df.groupby('Species').agg({'SepalWidthCm':np.average})
plt.scatter(df_sw['SepalWidthCm'],df_sw.index,color='red',label='Sepal Average Width')
df_sl=df.groupby('Species').agg({'SepalLengthCm':np.average})
plt.scatter(df_sl['SepalLengthCm'],df_sl.index,color='blue',label='Sepal Average Length')
df_pl=df.groupby('Species').agg({'PetalLengthCm':np.average})
plt.scatter(df_pl['PetalLengthCm'],df_pl.index,color='yellow',label='Petal Average Length')
df_pw=df.groupby('Species').agg({'PetalWidthCm':np.average})
plt.scatter(df_pw['PetalWidthCm'],df_pw.index,color='green',label='Petal Average Width')
plt.title('Average values of all the features')
plt.legend(fontsize='xx-small',loc='upper left',framealpha=0)
# Out:
# C:\Users\AishuandAshwini\anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\AishuandAshwini\anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df_sw=df.groupby('Species').agg({'SepalWidthCm':np.max})
plt.scatter(df_sw['SepalWidthCm'],df_sw.index,color='red',label='Sepal Maximum Width')
df_sl=df.groupby('Species').agg({'SepalLengthCm':np.max})
plt.scatter(df_sl['SepalLengthCm'],df_sl.index,color='blue',label='Sepal Maximum  Length')
df_pl=df.groupby('Species').agg({'PetalLengthCm':np.max})
plt.scatter(df_pl['PetalLengthCm'],df_pl.index,color='yellow',label='Petal Maximum  Length')
df_pw=df.groupby('Species').agg({'PetalWidthCm':np.max})
plt.scatter(df_pw['PetalWidthCm'],df_pw.index,color='green',label='Petal Maximum  Width')
plt.title('Maximum values of all the features')
plt.legend(fontsize='xx-small',loc='upper left',framealpha=0)

# %%
df_sw=df.groupby('Species').agg({'SepalWidthCm':np.min})
plt.scatter(df_sw['SepalWidthCm'],df_sw.index,color='red',label='Sepal Minimum Width')
df_sl=df.groupby('Species').agg({'SepalLengthCm':np.min})
plt.scatter(df_sl['SepalLengthCm'],df_sl.index,color='blue',label='Sepal Minimum  Length')
df_pl=df.groupby('Species').agg({'PetalLengthCm':np.min})
plt.scatter(df_pl['PetalLengthCm'],df_pl.index,color='yellow',label='Petal Minimum  Length')
df_pw=df.groupby('Species').agg({'PetalWidthCm':np.min})
plt.scatter(df_pw['PetalWidthCm'],df_pw.index,color='green',label='Petal Minimum  Width')
plt.title('Minimum values of all the features')
plt.legend(fontsize='xx-small',loc='upper left',framealpha=0)

# %%
df['SepalLengthCm'].hist()
plt.title('Count of each Sepal Length value')
plt.xlabel('Sepal Length')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['PetalLengthCm'].hist()
plt.title('Count of each Petal Length value')
plt.xlabel('Petal Length')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['SepalWidthCm'].hist()
plt.title('Count of each Sepal width value')
plt.xlabel('Sepal Width')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df['PetalWidthCm'].hist()
plt.title('Count of each Petal Width value')
plt.xlabel('Petal Width')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# Id
# 1             5.1           3.5            1.4           0.2        0
# 2             4.9           3.0            1.4           0.2        0
# 3             4.7           3.2            1.3           0.2        0
# 4             4.6           3.1            1.5           0.2        0
# 5             5.0           3.6            1.4           0.2        0

# %%
#  train dataset
from sklearn.model_selection import train_test_split
df1=df.reset_index(drop=True)
X=df1.drop(columns=['Species'])
Y=df1['Species']
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
model=LogisticRegression(solver='lbfgs', max_iter=1000)

# %%
#training model 
model.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#model prediction
predictions=model.predict(x_test)
print(predictions)
print(y_test)
# Out:
# [0 1 0 2 2 0 0 0 2 0 0 2 1 1 0 2 1 1 2 0 2 0 1 2 1 0 0 1 2 0 1 1 1 0 2 0 0
#  1 1 2 1 0 0 1 2]
# 16     0
# 52     1
# 25     0
# 124    2
# 142    2
# 44     0
# 32     0
# 11     0
# 104    2
# 46     0
# 34     0
# 137    2
# 74     1
# 98     1
# 24     0
# 116    2
# 106    2
# 79     1
# 109    2
# 35     0
# 123    2
# 2      0
# 54     1
# 147    2
# 95     1
# 8      0
# 33     0
# 91     1
# 113    2
# 45     0
# 84     1
# 88     1
# 94     1
# 12     0
# 100    2
# 14     0
# 27     0
# 85     1
# 86     1
# 108    2
# 50     1
# 31     0
# 22     0
# 78     1
# 144    2
# Name: Species, dtype: int32

# %%
print('Accuracy:',model.score(x_test,y_test)*100)
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# Accuracy: 97.77777777777777
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       0.93      1.00      0.97        14
#            2       1.00      0.92      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
# 0.9777777777777777

# %%
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,predictions)
sns.heatmap(mat.T,square=True,annot=True,fmt='d')

# %% [markdown]
# ##  Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier  
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
predictions=model.predict(x_test)
print(predictions)
print(y_test)
# Out:
# [0 1 0 2 2 0 0 0 2 0 0 2 1 1 0 2 1 1 2 0 2 0 1 2 1 0 0 1 2 0 1 1 1 0 2 0 0
#  1 1 2 1 0 0 1 2]
# 16     0
# 52     1
# 25     0
# 124    2
# 142    2
# 44     0
# 32     0
# 11     0
# 104    2
# 46     0
# 34     0
# 137    2
# 74     1
# 98     1
# 24     0
# 116    2
# 106    2
# 79     1
# 109    2
# 35     0
# 123    2
# 2      0
# 54     1
# 147    2
# 95     1
# 8      0
# 33     0
# 91     1
# 113    2
# 45     0
# 84     1
# 88     1
# 94     1
# 12     0
# 100    2
# 14     0
# 27     0
# 85     1
# 86     1
# 108    2
# 50     1
# 31     0
# 22     0
# 78     1
# 144    2
# Name: Species, dtype: int32

# %%
print('Accuracy:',model.score(x_test,y_test)*100)
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# Accuracy: 97.77777777777777
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       0.93      1.00      0.97        14
#            2       1.00      0.92      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
# 0.9777777777777777

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,predictions)
sns.heatmap(mat.T,square=True,annot=True,fmt='d')
